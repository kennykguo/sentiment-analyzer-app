# %%
import pandas as pd
import numpy as np
import spacy
import nltk
from nltk import pos_tag
from nltk.tokenize import word_tokenize
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from rake_nltk import Rake
import matplotlib.pyplot as plt
import re
import string

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Initialize VADER and RAKE
analyzer = SentimentIntensityAnalyzer()
rake = Rake()

# %%
def clean_text(text):
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub(r'\s+', ' ', text).strip()
    text = text.lower()
    return text

# %%
def perform_ner(texts):
    all_entities = []
    for text in texts:
        doc = nlp(text)
        entities = [(ent.text, ent.label_) for ent in doc.ents]
        all_entities.extend(entities)
    return all_entities

# %%
def get_pos_tags(texts):
    all_tags = []
    for text in texts:
        tokens = word_tokenize(text)
        tags = pos_tag(tokens)
        all_tags.extend(tags)
    return all_tags

# %%
def top_nouns_verbs_adjectives(tags, top_n=10):
    nouns = [word for word, pos in tags if pos in ['NN', 'NNS', 'NNP', 'NNPS']]
    verbs = [word for word, pos in tags if pos.startswith('VB')]
    adjectives = [word for word, pos in tags if pos in ['JJ', 'JJR', 'JJS']]
    
    return {
        'nouns': nltk.FreqDist(nouns).most_common(top_n),
        'verbs': nltk.FreqDist(verbs).most_common(top_n),
        'adjectives': nltk.FreqDist(adjectives).most_common(top_n)
    }

# %%
def detect_emotions(texts):
    all_scores = []
    for text in texts:
        sentiment = analyzer.polarity_scores(text)
        all_scores.append(sentiment['compound'])
    return all_scores

# %%
# Can update this functionality to generate keywords based on specific topics or related word meanings
def extract_keywords(texts):
    all_keywords = []
    for text in texts:
        rake.extract_keywords_from_text(text)
        keywords = rake.get_ranked_phrases()
        all_keywords.extend(keywords)
    return all_keywords

# %%
def analyze_sentiment_scores(scores):
    mean_score = np.mean(scores)
    return mean_score

# %%
def plot_sentiment_distribution(scores):
    plt.figure(figsize=(10, 6))
    plt.hist(scores, bins=20, edgecolor='black')
    plt.title('Sentiment Score Distribution')
    plt.xlabel('Sentiment Score')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# %%
def average_word_count(texts):
    word_counts = [len(text.split()) for text in texts]
    return np.mean(word_counts)

# %%
def import_and_process_data(file_path):
    df = pd.read_excel(file_path, header=None, names=['review'])
    reviews = df['review'].tolist()
    
    # Clean the entire list of reviews
    cleaned_reviews = [clean_text(review) for review in reviews]
    
    # NER
    entities = perform_ner(cleaned_reviews)
    
    # POS Tagging
    pos_tags = get_pos_tags(cleaned_reviews)
    top_pos_tags = top_nouns_verbs_adjectives(pos_tags)
    
    # Emotion Detection
    sentiment_scores = detect_emotions(cleaned_reviews)
    
    # Keyword Extraction
    keywords = extract_keywords(cleaned_reviews)
    
    # Compute statistics
    avg_sentiment_score = analyze_sentiment_scores(sentiment_scores)
    avg_word_count = average_word_count(reviews)
    print(f"Average Sentiment Score: {avg_sentiment_score}")
    print(f"Average Word Count per Review: {avg_word_count}")
    
    # NER
    print("\nNER:")
    print(set(entities))  # Print unique entities

    # POS
    print("\nTop POS Tags:")
    print('Nouns:')
    print(top_pos_tags['nouns'])
    print('Verbs:')
    print(top_pos_tags['verbs'])
    print('Adj:')
    print(top_pos_tags['adjectives'])

    # Keyword extraction
    print("\nKeywords Extracted:")
    print(set(keywords))  # Print unique keywords
    
    # Plot sentiment distribution
    plot_sentiment_distribution(sentiment_scores)

# Define the file path
file_path = 'sentiment_data/73.xlsx'

import_and_process_data(file_path)
# Out:
# Average Sentiment Score: 0.5701975609756098
# Average Word Count per Review: 52.46341463414634
#
# NER:
# {('25', 'DATE'), ('every few days', 'DATE'), ('day 2', 'DATE'), ('10', 'CARDINAL'), ('every morning', 'TIME'), ('about a month', 'DATE'), ('4 days', 'DATE'), ('korean', 'NORP'), ('daily', 'DATE'), ('one', 'CARDINAL'), ('the first day', 'DATE'), ('pas de fini', 'PERSON'), ('first', 'ORDINAL'), ('each night', 'TIME'), ('zero', 'CARDINAL'), ('4 hours', 'TIME'), ('1798', 'DATE'), ('the 30 minutes', 'TIME'), ('2', 'CARDINAL'), ('a month', 'DATE'), ('100', 'CARDINAL'), ('12', 'CARDINAL'), ('a few weeks', 'DATE'), ('second', 'ORDINAL'), ('first few days', 'DATE'), ('3rd', 'ORDINAL')}
#
# Top POS Tags:
# Nouns:
# [('i', 66), ('skin', 41), ('’', 19), ('t', 17), ('product', 15), ('essence', 13), ('texture', 11), ('ve', 9), ('toner', 8), ('m', 8)]
# Verbs:
# [('’', 34), ('is', 31), ('has', 18), ('using', 16), ('have', 15), ('i', 14), ('use', 13), ('was', 10), ('been', 9), ('love', 8)]
# Adj:
# [('i', 21), ('skin', 10), ('’', 10), ('s', 9), ('much', 7), ('good', 7), ('dry', 6), ('only', 6), ('great', 5), ('same', 5)]
#
# Keywords Extracted:
# {'anything changes', 'right amount', 'social media', 'moisture levels', 'reminder since', 'amazing product', 'small', 'absorbs quickly leaving', 'crazy dry sensitive', 'easily absorbed', 'skin ’', 'much softer', 'nice lightweight texture', 'ever used', 'highly doubt', 'nothing', 'long way', 'formula', 'give', 'product works', 'skincare product', 'cause pilling', 'absolutely love', 'koreanbased kproduct seller', 'product doesnt bother', 'soft', 'sodium hyaluronate hyaluronic acid use', 'top', 'second bottle', 'great', 'absorbs beautifully', 'pump dispenses', 'importantly', 'scent', 'skin feels', 'bean essence', 'also started using', 'run', 'cleansing oil everything else', 'skin loves', 'smells', 'feels', 'difference', 'negative reactions', 'significant improvement', 'cosrx snail mucin power essence bottles', 'skin feel', 'let anyone touch', 'worth', 'really good', 'residue', 'decrease', 'see', 'youre', 'use', 'looks', 'smoother', 'also', 'yet', 'much smoother', 'cleansing', 'product deserves one', 'might work', 'bit', 'crazy also', 'beauty filter lol', 'quite know', 'assumed', 'point didnt aggravate', 'seems', 'seem', 'still cannot believe', 'forget', 'havent', 'dry skin', 'hydrates well', 'regular product purchase', 'looks youthful right', 'like 12 lol also', 'sensitive skin highly recommend', 'definitely tell', 'downside', 'someone', 'definitely helped', 'could feel', 'offensive smell', 'day 2', 'reduce redness pretty apparent', 'light', 'skin feels plump', 'quality makes', 'actually cleared', 'skins aversion', 'feels like', 'quickly', 'serum', 'never looked better', 'packaging', '3rd bottle genuinely', 'face', 'healthy glow soft', 'recommend', 'dont even offer amazon prime', 'lot longer', 'stuff gave', 'fair review', 'ive', 'skin shiner', 'much makeup anymore', 'radiant immediately', 'working', 'snails', 'textured like', 'far', '25', 'products', 'scentless making', 'cause', 'makes skin fresh', 'skin look', 'skin', 'get past', 'overpowering', 'impressed', 'never look back', 'use retina', 'definitely repurchasing', 'worth buying', 'even need', 'attract water', 'liked', 'hydrating light', 'wait', 'lot like ha', 'kid', 'reason', 'evenly', 'luminous', 'service far', 'ahas one', 'retinols', 'smooth without', 'timefree beauty probably', 'cannot comprehend', 'ways', 'stuff helps heal acne', 'product', 'would ’', 'dry skin acne', 'every morning', 'name suited', 'ordering', 'dont', 'honestly', 'skincare products', 'dry combination sensitive skin', 'first time', 'kind', 'skin reacts differently', 'noticed', 'itll help draw', 'definitely', '10 would recommend', 'pleasant', 'acne', 'affordable', 'everything else', 'decided', 'skin feel hydrated', 'gooey consistency', 'essence', 'great improvement since', 'hydrated', 'good', 'last', 'moisturizer', 'healed', 'amazing', 'long', 'definitely continue', 'fresh', 'different toner', 'big result', 'nice light texture', 'hydrate', 'bumps', 'couple', 'eczema', 'work', 'budget overall', 'hydration', 'constantly repurchasing', 'caused', 'definitely recommend', 'redness', 'woke', 'put', 'oml', 'may', 'repurchase', 'afterwards', 'psoriasiseczema skin', 'smoothly', 'smooth', 'would highly highly highly recommend', 'little concerned', '30 minutes', 'goodsoothing', 'skin looks plumper', 'lightweight', 'almost', 'minimal', 'skincare routine', 'pair', 'never bought', 'pimples took', 'say', 'company', 'zero reaction', 'maybe', 'read', 'big', 'wasnt', 'amazing definitely recommend', 'dries', 'irritation', 'month', 'made', 'stickiness behind 10', 'ridiculous amount', '’', 'applying', 'light slightly sticky texture', 'stuff makes', 'didnt', 'lightweight slightly sticky texture', 'usually write reviews', 'toner', 'ive heard', 'satisfied', 'product ive used', 'absorbs quickly without leaving', 'regular moisturizers ofc', 'face used', 'otherwise', 'clear since', 'heal', 'ordered korean products received dublicate productsim happy', 'result', 'wasnt convinced', 'genuinely', 'ive bought 2', 'fine', 'strong fragrance ...

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchtext.vocab import build_vocab_from_iterator
import torchtext.transforms as T
import io

# Define your hyperparameters
block_size = 256
n_embd = 768
n_head = 12
n_layer = 2
dropout = 0.4
output_size = 2

# Load vocabulary
def yield_tokens(file_path):
    with io.open(file_path, encoding='utf-8') as f:
        for line in f:
            yield [line.split("\t")[0]]

vocab = build_vocab_from_iterator(yield_tokens("sentencepiece/transformer.vocab"), 
                                  specials=['<cls>', '<pad>', '<eos>', '<unk>'], 
                                  special_first=True)
vocab.set_default_index(vocab['<unk>'])

# Define text transform
text_transform = T.Sequential(
    T.SentencePieceTokenizer("sentencepiece/transformer.model"),
    T.VocabTransform(vocab),
    T.AddToken(vocab['<cls>'], begin=True),
    T.Truncate(max_seq_len=254),
    T.AddToken(vocab['<eos>'], begin=False),
    T.ToTensor(padding_value=vocab['<pad>']),
    T.PadTransform(max_length=256, pad_value=0),
)

class FeedForward(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )
    
    def forward(self, x):
        return self.net(x)

class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)
        q = self.query(x)
        wei = q @ k.transpose(-2, -1) * C ** -0.5
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        v = self.value(x)
        out = wei @ v
        return out, wei

class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = []
        attn_weights = []
        for h in self.heads:
            head_out, head_attn = h(x)
            out.append(head_out)
            attn_weights.append(head_attn)
        out = torch.cat(out, dim=-1)
        out = self.dropout(self.proj(out))
        attn_weights = torch.stack(attn_weights, dim=1)
        return out, attn_weights

class Block(nn.Module):
    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ffwd = FeedForward(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        sa_out, attn_weights = self.sa(self.ln1(x))
        x = x + sa_out
        x = x + self.ffwd(self.ln2(x))
        return x, attn_weights

class Transformer(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(len(vocab), n_embd)
        self.position_embedding_table = nn.Embedding(block_size + 1, n_embd)
        self.blocks = nn.ModuleList([Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, output_size)
 
    def forward(self, idx):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=idx.device))
        x = tok_emb + pos_emb

        attn_weights = None
        for i, block in enumerate(self.blocks):
            x, attn_weights = block(x)

        x = self.ln_f(x)
        logits = self.lm_head(x[:, 0, :])

        return logits, attn_weights

# %%
import torch
import torch.nn.functional as F
def predict_single_text(model, text, text_transform, vocab):
    device = next(model.parameters()).device
    tokens = text_transform([text]).to(device)
    
    with torch.no_grad():
        logits, attn_weights = model(tokens)
    
    probs = F.softmax(logits, dim=-1)
    label = torch.argmax(probs, dim=1)
    
    # Analyze attention weights
    att_map = attn_weights[0, -1, :, :]  # Last head, first sample
    att_weights = att_map[0]  # Attention weights for the [CLS] token
    top10 = att_weights.argsort(descending=True)[:10]
    top10_tokens = [vocab.lookup_token(tokens[0][idx].item()) for idx in top10]
    
    prediction = 'positive' if label.item() == 1 else 'negative'
    return prediction, top10_tokens

def load_model(model_path):
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model = Transformer()
    model.load_state_dict(torch.load(model_path, map_location=device))
    model = model.to(device)
    model.eval()
    return model

# %%
import pandas as pd
import torch
import sys
import os

def predict_single_text(model, text, text_transform, vocab):
    device = next(model.parameters()).device
    tokens = text_transform([text]).to(device)
    
    with torch.no_grad():
        logits, attn_weights = model(tokens)
    
    probs = torch.nn.functional.softmax(logits, dim=-1)
    label = torch.argmax(probs, dim=1)
    
    # Analyze attention weights
    att_map = attn_weights[0, -1, :, :]  # Last head, first sample
    att_weights = att_map[0]  # Attention weights for the [CLS] token
    top10 = att_weights.argsort(descending=True)[:10]
    top10_tokens = [vocab.lookup_token(tokens[0][idx].item()) for idx in top10]
    
    prediction = 'positive' if label.item() == 1 else 'negative'
    return prediction, top10_tokens

def import_and_process_data(file_path):
    df = pd.read_excel(file_path, header=None, names=['review'])
    reviews = df['review'].tolist()
    
    # Clean the entire list of reviews
    cleaned_reviews = [clean_text(review) for review in reviews]
    
    # NER
    entities = perform_ner(cleaned_reviews)
    
    # POS Tagging
    pos_tags = get_pos_tags(cleaned_reviews)
    top_pos_tags = top_nouns_verbs_adjectives(pos_tags)
    
    # Emotion Detection
    sentiment_scores = detect_emotions(cleaned_reviews)
    
    # Keyword Extraction
    keywords = extract_keywords(cleaned_reviews)
    
    # Compute statistics
    avg_sentiment_score = analyze_sentiment_scores(sentiment_scores)
    avg_word_count = average_word_count(reviews)
    print(f"Average Sentiment Score: {avg_sentiment_score}")
    print(f"Average Word Count per Review: {avg_word_count}")
    
    # NER
    print("\nNER:")
    print(set(entities))  # Print unique entities

    # POS
    print("\nTop POS Tags:")
    print('Nouns:')
    print(top_pos_tags['nouns'])
    print('Verbs:')
    print(top_pos_tags['verbs'])
    print('Adj:')
    print(top_pos_tags['adjectives'])

    # Keyword extraction
    print("\nKeywords Extracted:")
    print(set(keywords))  # Print unique keywords
    
    # Plot sentiment distribution
    plot_sentiment_distribution(sentiment_scores)

    # PyTorch Model Inference
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model = Transformer()
    model.load_state_dict(torch.load('model_weights/gpt.pth'))
    model = model.to(device)
    model.eval()

    print("\nPyTorch Model Predictions:")
    for i, review in enumerate(cleaned_reviews):
        prediction, top_words = predict_single_text(model, review, text_transform, vocab)
        print(f"Review {i+1} - Prediction: {prediction}")
        print(f"Top words influencing the prediction: {', '.join(top_words)}")
        print()

# Define the file path
file_path = 'sentiment_data/73.xlsx'

import_and_process_data(file_path)
# Out:
# Average Sentiment Score: 0.5701975609756098
# Average Word Count per Review: 52.46341463414634
#
# NER:
# {('25', 'DATE'), ('every few days', 'DATE'), ('day 2', 'DATE'), ('10', 'CARDINAL'), ('every morning', 'TIME'), ('about a month', 'DATE'), ('4 days', 'DATE'), ('korean', 'NORP'), ('daily', 'DATE'), ('one', 'CARDINAL'), ('the first day', 'DATE'), ('pas de fini', 'PERSON'), ('first', 'ORDINAL'), ('each night', 'TIME'), ('zero', 'CARDINAL'), ('4 hours', 'TIME'), ('1798', 'DATE'), ('the 30 minutes', 'TIME'), ('2', 'CARDINAL'), ('a month', 'DATE'), ('100', 'CARDINAL'), ('12', 'CARDINAL'), ('a few weeks', 'DATE'), ('second', 'ORDINAL'), ('first few days', 'DATE'), ('3rd', 'ORDINAL')}
#
# Top POS Tags:
# Nouns:
# [('i', 66), ('skin', 41), ('’', 19), ('t', 17), ('product', 15), ('essence', 13), ('texture', 11), ('ve', 9), ('toner', 8), ('m', 8)]
# Verbs:
# [('’', 34), ('is', 31), ('has', 18), ('using', 16), ('have', 15), ('i', 14), ('use', 13), ('was', 10), ('been', 9), ('love', 8)]
# Adj:
# [('i', 21), ('skin', 10), ('’', 10), ('s', 9), ('much', 7), ('good', 7), ('dry', 6), ('only', 6), ('great', 5), ('same', 5)]
#
# Keywords Extracted:
# {'anything changes', 'right amount', 'social media', 'moisture levels', 'reminder since', 'amazing product', 'small', 'absorbs quickly leaving', 'crazy dry sensitive', 'easily absorbed', 'skin ’', 'much softer', 'nice lightweight texture', 'ever used', 'highly doubt', 'nothing', 'long way', 'formula', 'give', 'product works', 'skincare product', 'cause pilling', 'absolutely love', 'koreanbased kproduct seller', 'product doesnt bother', 'soft', 'sodium hyaluronate hyaluronic acid use', 'top', 'second bottle', 'great', 'absorbs beautifully', 'pump dispenses', 'importantly', 'scent', 'skin feels', 'bean essence', 'also started using', 'run', 'cleansing oil everything else', 'skin loves', 'smells', 'feels', 'difference', 'negative reactions', 'significant improvement', 'cosrx snail mucin power essence bottles', 'skin feel', 'let anyone touch', 'worth', 'really good', 'residue', 'decrease', 'see', 'youre', 'use', 'looks', 'smoother', 'also', 'yet', 'much smoother', 'cleansing', 'product deserves one', 'might work', 'bit', 'crazy also', 'beauty filter lol', 'quite know', 'assumed', 'point didnt aggravate', 'seems', 'seem', 'still cannot believe', 'forget', 'havent', 'dry skin', 'hydrates well', 'regular product purchase', 'looks youthful right', 'like 12 lol also', 'sensitive skin highly recommend', 'definitely tell', 'downside', 'someone', 'definitely helped', 'could feel', 'offensive smell', 'day 2', 'reduce redness pretty apparent', 'light', 'skin feels plump', 'quality makes', 'actually cleared', 'skins aversion', 'feels like', 'quickly', 'serum', 'never looked better', 'packaging', '3rd bottle genuinely', 'face', 'healthy glow soft', 'recommend', 'dont even offer amazon prime', 'lot longer', 'stuff gave', 'fair review', 'ive', 'skin shiner', 'much makeup anymore', 'radiant immediately', 'working', 'snails', 'textured like', 'far', '25', 'products', 'scentless making', 'cause', 'makes skin fresh', 'skin look', 'skin', 'get past', 'overpowering', 'impressed', 'never look back', 'use retina', 'definitely repurchasing', 'worth buying', 'even need', 'attract water', 'liked', 'hydrating light', 'wait', 'lot like ha', 'kid', 'reason', 'evenly', 'luminous', 'service far', 'ahas one', 'retinols', 'smooth without', 'timefree beauty probably', 'cannot comprehend', 'ways', 'stuff helps heal acne', 'product', 'would ’', 'dry skin acne', 'every morning', 'name suited', 'ordering', 'dont', 'honestly', 'skincare products', 'dry combination sensitive skin', 'first time', 'kind', 'skin reacts differently', 'noticed', 'itll help draw', 'definitely', '10 would recommend', 'pleasant', 'acne', 'affordable', 'everything else', 'decided', 'skin feel hydrated', 'gooey consistency', 'essence', 'great improvement since', 'hydrated', 'good', 'last', 'moisturizer', 'healed', 'amazing', 'long', 'definitely continue', 'fresh', 'different toner', 'big result', 'nice light texture', 'hydrate', 'bumps', 'couple', 'eczema', 'work', 'budget overall', 'hydration', 'constantly repurchasing', 'caused', 'definitely recommend', 'redness', 'woke', 'put', 'oml', 'may', 'repurchase', 'afterwards', 'psoriasiseczema skin', 'smoothly', 'smooth', 'would highly highly highly recommend', 'little concerned', '30 minutes', 'goodsoothing', 'skin looks plumper', 'lightweight', 'almost', 'minimal', 'skincare routine', 'pair', 'never bought', 'pimples took', 'say', 'company', 'zero reaction', 'maybe', 'read', 'big', 'wasnt', 'amazing definitely recommend', 'dries', 'irritation', 'month', 'made', 'stickiness behind 10', 'ridiculous amount', '’', 'applying', 'light slightly sticky texture', 'stuff makes', 'didnt', 'lightweight slightly sticky texture', 'usually write reviews', 'toner', 'ive heard', 'satisfied', 'product ive used', 'absorbs quickly without leaving', 'regular moisturizers ofc', 'face used', 'otherwise', 'clear since', 'heal', 'ordered korean products received dublicate productsim happy', 'result', 'wasnt convinced', 'genuinely', 'ive bought 2', 'fine', 'strong fragrance ...
# PyTorch Model Predictions:
# Review 1 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁the, s, er, ▁bean, ▁skin, ▁my, <cls>, ▁has, <cls>
#
# Review 2 - Prediction: positive
# Top words influencing the prediction: <cls>, ▁it, ▁buying, ▁love, <cls>, ▁i, <cls>, <cls>, <cls>, <cls>
#
# Review 3 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁importantly, ▁have, ▁skin, ▁absorbed, ▁easily, <cls>, ▁, ▁i, s
#
# Review 4 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁to, ▁skin, ▁it, ▁my, ▁its, ▁love, <cls>, ▁product, ▁i
#
# Review 5 - Prediction: positive
# Top words influencing the prediction: <cls>, ▁feel, ▁it, ▁love, <cls>, ▁does, ▁i, ▁heavy, <cls>, ▁far
#
# Review 6 - Prediction: positive
# Top words influencing the prediction: ▁skin, ▁in, ▁have, ▁about, <cls>, ▁for, ▁i, ▁been, ▁improvement, ▁it
#
# Review 7 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁highly, ▁love, less, ▁skin, ▁its, <cls>, ▁making, ▁went, <cls>
#
# Review 8 - Prediction: positive
# Top words influencing the prediction: ▁i, ▁recommend, ▁and, ▁it, ▁so, ▁love, ▁product, <cls>, ▁afford, ▁about
#
# Review 9 - Prediction: positive
# Top words influencing the prediction: <cls>, ▁skin, ▁and, <cls>, <cls>, ▁leaves, <cls>, <cls>, <cls>, <cls>
#
# Review 10 - Prediction: positive
# Top words influencing the prediction: ▁product, ▁bottle, <cls>, ▁awesome, <eos>, ▁non, ▁and, <cls>, <cls>, <cls>
#
# Review 11 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁it, ▁the, ▁skin, ▁skin, t, ▁remember, ▁my, ▁was, ▁so
#
# Review 12 - Prediction: positive
# Top words influencing the prediction: ▁they, ve, ▁skin, ▁2, ▁for, <cls>, ▁me, ▁are, x, ▁i
#
# Review 13 - Prediction: positive
# Top words influencing the prediction: ▁loved, <cls>, ▁it, <cls>, <cls>, <cls>, <cls>, <cls>, <cls>, <cls>
#
# Review 14 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁its, <cls>, ▁it, ▁hype, <cls>, <cls>, <cls>, <cls>, <cls>
#
# Review 15 - Prediction: positive
# Top words influencing the prediction: <cls>, <cls>, ▁i, <cls>, <cls>, m, <cls>, <cls>, <cls>, <cls>
#
# Review 16 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁takes, s, ▁in, <cls>, ▁feels, ▁ha, ist, <cls>, <cls>
#
# Review 17 - Prediction: positive
# Top words influencing the prediction: ▁so, <cls>, ▁so, <cls>, ▁far, <cls>, <cls>, <cls>, <cls>, <cls>
#
# Review 18 - Prediction: positive
# Top words influencing the prediction: <cls>, ▁must, ▁have, <cls>, <cls>, <cls>, <cls>, <cls>, <cls>, <cls>
#
# Review 19 - Prediction: positive
# Top words influencing the prediction: ▁so, ▁caused, ve, ing, ▁resid, t, ▁hasn, er, ▁leaving, m
#
# Review 20 - Prediction: positive
# Top words influencing the prediction: er, ▁it, ▁it, ▁loved, rd, <cls>, ▁i, <cls>, ▁bottle, <cls>
#
# Review 21 - Prediction: positive
# Top words influencing the prediction: <cls>, <cls>, <cls>, <cls>, <cls>, <cls>, <cls>, <cls>, <cls>, <cls>
#
# Review 22 - Prediction: positive
# Top words influencing the prediction: ▁it, <cls>, <cls>, <cls>, d, <cls>, <cls>, <cls>, <cls>, s
#
# Review 23 - Prediction: positive
# Top words influencing the prediction: <cls>, ▁it, ▁product, ▁skin, <cls>, ▁radiant, ▁amazing, <cls>, <cls>, <cls>
#
# Review 24 - Prediction: positive
# Top words influencing the prediction: ▁light, ▁the, ▁significant, ▁skin, ve, ▁twice, ▁it, ▁pleasant, ▁and, ▁irritate
#
# Review 25 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁the, ▁the, ▁the, ▁if, ▁the, ing, ▁may, ▁started, ▁snail
#
# Review 26 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁it, ▁it, ▁don, ▁just, ▁does, <cls>, ▁twice, ▁it, t
#
# Review 27 - Prediction: positive
# Top words influencing the prediction: ▁tr, ant, ini, <cls>, du, s, <cls>, <cls>, <cls>, <cls>
#
# Review 28 - Prediction: positive
# Top words influencing the prediction: <cls>, ▁love, <cls>, ▁i, <cls>, <cls>, <cls>, <cls>, <cls>, <cls>
#
# Review 29 - Prediction: negative
# Top words influencing the prediction: ▁skin, ▁the, ▁right, ▁the, er, ▁much, ▁skin, t, ▁looks, t
#
# Review 30 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁the, ▁the, ▁and, ▁was, ▁was, ▁skin, ve, ▁it, ▁have
#
# Review 31 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁the, ▁the, ▁2, ▁the, ▁the, ▁was, ▁differently, ▁woke, ▁react
#
# Review 32 - Prediction: negative
# Top words influencing the prediction: ▁the, ▁the, ▁the, ▁the, ▁the, ▁its, ▁first, ▁in, ▁nothing, ▁far
#
# Review 33 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁suited, ▁in, ▁the, ▁because, ▁bit, ▁rude, ▁the, ▁it, al
#
# Review 34 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁the, ▁the, ▁the, ▁the, ue, ▁and, ze, ▁it, ▁goo
#
# Review 35 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁the, ▁the, ▁in, ▁levels, d, t, ol, ist, ▁it
#
# Review 36 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁the, ▁it, ▁feels, ▁become, ▁in, s, ▁and, ▁skin, ▁so
#
# Review 37 - Prediction: positive
# Top words influencing the prediction: ▁skin, ▁the, ▁the, ▁the, ▁it, ▁haven, ▁without, ve, ▁only, ▁light
#
# Review 38 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁and, ▁it, ▁haven, ▁it, ▁continue, ing, ▁skin, ▁sticky, t
#
# Review 39 - Prediction: positive
# Top words influencing the prediction: ▁in, ▁the, ▁the, ▁the, ▁so, ▁budget, ▁well, ▁bit, ve, ▁skin
#
# Review 40 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁the, ▁the, ▁the, ▁the, ▁quickly, ▁right, ▁so, ▁luminous, er
#
# Review 41 - Prediction: positive
# Top words influencing the prediction: ▁the, ▁the, ▁the, ▁the, ▁the, care, ▁it, ▁it, ▁in, ▁it
